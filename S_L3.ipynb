# %%
age = 25
print ("Age:" + str(age))

int (age)/2
# Out:
# Age:25

# %%
student_name = "John Doe"
print("Student Name:" + student_name)

# %%
score = 10
score = 20
print (score, score) )

# %%
amount = 12000
vat = amount * 7.5
print(vat)

# %%
amount = 12000
vat = 0.075
vat = amount * vat
print(vat)
# Out:
# 900.0

# %%
print(2 + 3 * 4)
print((2 + 3) * 4)
print(2 ** 3 ** 2)
print(-17 // 5)
# Out:
# 14
# 20
# 512
# -4

# %%
totalSeconds = 7385
hours= 60 * 7385 / 24
minutes = 60 * 7385
second = 7385 /60

print(hours, minutes, second)
# Out:
# 18462.5 443100 123.08333333333333

# %%
print (3.14 * 3 ** 2)
print (int(3.77))
print (round(3.77))
print(int("33"))
print (float(22))
# Out:
# 28.26
# 3
# 4
# 33
# 22.0

# %%
print (int(round(float("3.7"))))
# Out:
# 4

# %%
numnber = input ("Enter a number")
print(name)
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
help (round)
# Out:
# Help on built-in function round in module builtins:
#
# round(number, ndigits=None)
#     Round a number to a given precision in decimal digits.
#
#     The return value is an integer if ndigits is omitted or None.  Otherwise
#     the return value has the same type as the number.  ndigits may be negative.

# %%
print(abs(-7), round(3.14159, 3), max(3, 12), min(3, 9, 1))
# Out:
# 7 3.142 12 1
